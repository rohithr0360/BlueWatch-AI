# %%
import os
import yaml

# Assume images and labels are your dataset variables
images = "/kaggle/input/yolov5s-data/train/images"
labels = "/kaggle/input/yolov5s-data/train/labels"

# Define data.yaml file
data_yaml = {
    'train': f'{images}',
    'val': f'{images}',
    'nc': 1,  # Replace with the number of classes in your dataset
    'names': ['Plastic']  # Replace with your class names
}

# Save data.yaml
with open(f'data.yaml', 'w') as yaml_file:
    yaml.dump(data_yaml, yaml_file, default_flow_style=False)

# Change to the

# %%
# !pip install ultralytics
# Out:
# ...
#   Obtaining dependency information for ultralytics from https://files.pythonhosted.org/packages/d3/05/5a98fcd5e405d89f293ddd74ac8dc3cc6940306adbfeaf343a3e6bd5d6d9/ultralytics-8.1.5-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 kB 788.6 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 702.8/702.8 kB 5.7 MB/s eta 0:00:0000:0100:01
# ...

# %%
from ultralytics import YOLO

# %%
model = YOLO()

# %%
model.train(data="data.yaml",epochs = 10)
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
403875d437de532eae13ffbd39f3b71972cc48cc

# %%
# !yolo task=detect mode=val model='/kaggle/working/runs/detect/train4/weights/best.pt' data="data.yaml"
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /kaggle/input/yolov5s-data/train/labels... 1886 images, 0 backgrou
# val: WARNING ⚠️ Cache directory /kaggle/input/yolov5s-data/train is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1886       2894      0.826      0.676      0.784      0.429
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Speed: 0.3ms preprocess, 3.8ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
from IPython.display import Image, display

image_path = '/kaggle/working/runs/detect/val/confusion_matrix.png'
display(Image(filename=image_path))

# %%
# !yolo task=detect mode=predict model='/kaggle/working/runs/detect/train4/weights/best.pt' conf = 0.25 source="/kaggle/input/yolov5s-data/test/images"
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/621 /kaggle/input/yolov5s-data/test/images/13_jpg.rf.66bfb9ab5d1ddcfa48351a275b662de0.jpg: 640x640 1 Plastic, 8.4ms
# image 2/621 /kaggle/input/yolov5s-data/test/images/15_jpg.rf.c921a18631de7ff12168f4f1b9bf4210.jpg: 640x640 5 Plastics, 7.4ms
# image 3/621 /kaggle/input/yolov5s-data/test/images/26_jpg.rf.30ebcae5f6d3f646c1f12e666d4dcdf9.jpg: 640x640 2 Plastics, 7.3ms
# image 4/621 /kaggle/input/yolov5s-data/test/images/3_jpg.rf.b5a1109b740523b0b26bd41559856253.jpg: 640x640 (no detections), 7.3ms
# image 5/621 /kaggle/input/yolov5s-data/test/images/4_jpg.rf.468e8403cb432b60d298ad2d01f2d4ea.jpg: 640x640 3 Plastics, 7.3ms
# image 6/621 /kaggle/input/yolov5s-data/test/images/final-inference-1_png.rf.12bf20a5c8a6d9779507cb05f33fac20.jpg: 640x640 1 Plastic, 7.3ms
# ...

# %%
from IPython.display import Image, display

image_path = '/kaggle/working/runs/detect/predict/frame_00875_png.rf.30d374b069274d9d259fae6f446adf51.jpg'
display(Image(filename=image_path))

# %%
video_path = '/kaggle/input/test-video/Stunning New Video Shows Massive Plastic Debris In Ocean _ NBC Nightly News.mp4'

# %%
# !yolo task=detect mode=predict model='/kaggle/working/runs/detect/train4/weights/best.pt' conf = 0.25 source=!yolo task=detect mode=predict model='/kaggle/working/runs/detect/train4/weights/best.pt' conf = 0.25 source="/kaggle/input/test-video/Stunning New Video Shows Massive Plastic Debris In Ocean _ NBC Nightly News.mp4"
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/3062) /kaggle/input/test-video/Stunning New Video Shows Massive Plastic Debris In Ocean _ NBC Nightly News.mp4: 384x640 9 Plastics, 82.5ms
# video 1/1 (2/3062) /kaggle/input/test-video/Stunning New Video Shows Massive Plastic Debris In Ocean _ NBC Nightly News.mp4: 384x640 9 Plastics, 6.7ms
# video 1/1 (3/3062) /kaggle/input/test-video/Stunning New Video Shows Massive Plastic Debris In Ocean _ NBC Nightly News.mp4: 384x640 10 Plastics, 7.7ms
# video 1/1 (4/3062) /kaggle/input/test-video/Stunning New Video Shows Massive Plastic Debris In Ocean _ NBC Nightly News.mp4: 384x640 9 Plastics, 6.2ms
# video 1/1 (5/3062) /kaggle/input/test-video/Stunning New Video Shows Massive Plastic Debris In Ocean _ NBC Nightly News.mp4: 384x640 10 Plastics, 5.8ms
# ...
